# %%
import cv2
import dlib
import os
import numpy as np
import matplotlib.pyplot as plt
from imutils import paths
import tensorflow as tf
import _pickle as pkl
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
imagepaths=list(paths.list_images("Lara"))

# %%
imagepaths
# Out:
# ['Lara\\angle_+00+00+00.png',
#  'Lara\\angle_+00+00+05.png',
#  'Lara\\angle_+00+00+10.png',
#  'Lara\\angle_+00+00+15.png',
#  'Lara\\angle_+00+00+20.png',
#  'Lara\\angle_+00+00-05.png',
#  'Lara\\angle_+00+00-10.png',
#  'Lara\\angle_+00+00-15.png',
#  'Lara\\angle_+00+00-20.png',
#  'Lara\\angle_+00+05+00.png',
#  'Lara\\angle_+00+05+05.png',
#  'Lara\\angle_+00+05+10.png',
#  'Lara\\angle_+00+05+15.png',
#  'Lara\\angle_+00+05+20.png',
#  'Lara\\angle_+00+05-05.png',
#  'Lara\\angle_+00+05-10.png',
#  'Lara\\angle_+00+05-15.png',
#  'Lara\\angle_+00+05-20.png',
#  'Lara\\angle_+00+10+00.png',
#  'Lara\\angle_+00+10+05.png',
#  'Lara\\angle_+00+10+10.png',
#  'Lara\\angle_+00+10+15.png',
#  'Lara\\angle_+00+10+20.png',
#  'Lara\\angle_+00+10-05.png',
#  'Lara\\angle_+00+10-10.png',
#  'Lara\\angle_+00+10-15.png',
#  'Lara\\angle_+00+10-20.png',
#  'Lara\\angle_+00+15+00.png',
#  'Lara\\angle_+00+15+05.png',
#  'Lara\\angle_+00+15+10.png',
#  'Lara\\angle_+00+15+15.png',
#  'Lara\\angle_+00+15+20.png',
#  'Lara\\angle_+00+15-05.png',
#  'Lara\\angle_+00+15-10.png',
#  'Lara\\angle_+00+15-15.png',
#  'Lara\\angle_+00+15-20.png',
#  'Lara\\angle_+00+20+00.png',
#  'Lara\\angle_+00+20+05.png',
#  'Lara\\angle_+00+20+10(1).png',
#  'Lara\\angle_+00+20+10.png',
#  'Lara\\angle_+00+20+15.png',
#  'Lara\\angle_+00+20+20.png',
#  'Lara\\angle_+00+20-05.png',
#  'Lara\\angle_+00+20-10.png',
#  'Lara\\angle_+00+20-15.png',
#  'Lara\\angle_+00+20-20.png',
#  'Lara\\angle_+00+25+00.png',
#  'Lara\\angle_+00+25+05.png',
#  'Lara\\angle_+00+25+10.png',
#  'Lara\\angle_+00+25+15.png',
#  'Lara\\angle_+00+25+20.png',
#  'Lara\\angle_+00+25-05.png',
#  'Lara\\angle_+00+25-10.png',
#  'Lara\\angle_+00+25-15.png',
#  'Lara\\angle_+00+25-20.png',
#  'Lara\\angle_+00+30+00.png',
#  'Lara\\angle_+00+30+05.png',
#  'Lara\\angle_+00+30+10.png',
#  'Lara\\angle_+00+30+15(1).png',
#  'Lara\\angle_+00+30+15.png',
#  'Lara\\angle_+00+30+20.png',
#  'Lara\\angle_+00+30-05.png',
#  'Lara\\angle_+00+30-10.png',
#  'Lara\\angle_+00+30-15.png',
#  'Lara\\angle_+00+30-20.png',
#  'Lara\\angle_+00+35+00.png',
#  'Lara\\angle_+00+35+05.png',
#  'Lara\\angle_+00+35+10.png',
#  'Lara\\angle_+00+35+15.png',
#  'Lara\\angle_+00+35+20.png',
#  'Lara\\angle_+00+35-05.png',
#  'Lara\\angle_+00+35-10.png',
#  'Lara\\angle_+00+35-15.png',
#  'Lara\\angle_+00+35-20.png',
#  'Lara\\angle_+00+40+00.png',
#  'Lara\\angle_+00+40+05.png',
#  'Lara\\angle_+00+40+10.png',
#  'Lara\\angle_+00+40+15.png',
#  'Lara\\angle_+00+40+20.png',
#  'Lara\\angle_+00+40-05.png',
#  'Lara\\angle_+00+40-10.png',
#  'Lara\\angle_+00+40-15.png',
#  'Lara\\angle_+00+40-20.png',
#  'Lara\\angle_+00+45+00.png',
#  'Lara\\angle_+00+45+05.png',
#  'Lara\\angle_+00+45+10.png',
#  'Lara\\angle_+00+45+15.png',
#  'Lara\\angle_+00+45+20.png',
#  'Lara\\angle_+00+45-05.png',
#  'Lara\\angle_+00+45-10.png',
#  'Lara\\angle_+00+45-15.png',
#  'Lara\\angle_+00+45-20.png',
#  'Lara\\angle_+00-05+00(1).png',
#  'Lara\\angle_+00-05+00.png',
#  'Lara\\angle_+00-05+05.png',
#  'Lara\\angle_+00-05+10.png',
#  'Lara\\angle_+00-05+15.png',
#  'Lara\\angle_+00-05+20.png',
#  'Lara\\angle_+00-05-05.png',
#  'Lara\\angle_+00-05-10.png',
#  'Lara\\angle_+00-05-15.png',
#  'Lara\\angle_+00-05-20.png',
#  'Lara\\angle_+00-10+00.png',
#  'Lara\\angle_+00-10+05.png',
#  'Lara\\angle_+00-10+10.png',
#  'Lara\\angle_+00-10+15(1).png',
#  'Lara\\angle_+00-10+15.png',
#  'Lara\\angle_+00-10+20.png',
#  'Lara\\angle_+00-10-05.png',
#  'Lara\\angle_+00-10-10(1).png',
#  'Lara\\angle_+00-10-10.png',
#  'Lara\\angle_+00-10-15.png',
#  'Lara\\angle_+00-10-20.png',
#  'Lara\\angle_+00-15+00.png',
#  'Lara\\angle_+00-15+05.png',
#  'Lara\\angle_+00-15+10.png',
#  'Lara\\angle_+00-15+15.png',
#  'Lara\\angle_+00-15+20.png',
#  'Lara\\angle_+00-15-05.png',
#  'Lara\\angle_+00-15-10.png',
#  'Lara\\angle_+00-15-15.png',
#  'Lara\\angle_+00-15-20.png',
#  'Lara\\angle_+00-20+00.png',
#  'Lara\\angle_+00-20+05.png',
#  'Lara\\angle_+00-20+10.png',
#  'Lara\\angle_+00-20+15.png',
#  'Lara\\angle_+00-20+20.png',
#  'Lara\\angle_+00-20-05.png',
#  'Lara\\angle_+00-20-10.png',
#  'Lara\\angle_+00-20-15.png',
#  'Lara\\angle_+00-20-20.png',
#  'Lara\\angle_+00-25+00.png',
#  'Lara\\angle_+00-25+05.png',
#  'Lara\\angle_+00-25+10.png',
#  'Lara\\angle_+00-25+15.png',
#  'Lara\\angle_+00-25+20.png',
#  'Lara\\angle_+00-25-05.png',
#  'Lara\\angle_+00-25-10.png',
#  'Lara\\angle_+00-25-15.png',
#  'Lara\\angle_+00-25-20.png',
#  'Lara\\angle_+00-30+00.png',
#  'Lara\\angle_+00-30+05.png',
#  'Lara\\angle_+00-30+10.png',
#  'Lara\\angle_+00-30+15.png',
#  'Lara\\angle_+00-30+20.png',
#  'Lara\\angle_+00-30-05.png',
#  'Lara\\angle_+00-30-10.png',
#  'Lara\\angle_+00-30-15.png',
#  'Lara\\angle_+00-30-20.png',
#  'Lara\\angle_+00-35+00.png',
#  'Lara\\angle_+00-35+05.png',
#  'Lara\\angle_+00-35+10.png',
#  'Lara\\angle_+00-35+15.png',
#  'Lara\\angle_+00-35+20.png',
#  'Lara\\angle_+00-35-05.png',
#  'Lara\\angle_+00-35-10.png',
#  'Lara\\angle_+00-35-15.png',
#  'Lara\\angle_+00-35-20.png',
#  'Lara\\angle_+00-40+00.png',
#  'Lara\\angle_+00-40+05.png',
#  'Lara\\angle_+00-40+10.png',
#  'Lara\\angle_+00-40+15.png',
#  'Lara\\angle_+00-40+20.png',
#  'Lara\\angle_+00-40-05.png',
#  'Lara\\angle_+00-40-10.png',
#  'Lara\\angle_+00-40-15.png',
#  'Lara\\angle_+00-40-20.png',
#  'Lara\\angle_+00-45+00(1).png',
#  'Lara\\angle_+00-45+00.png',
#  'Lara\\angle_+00-45+05.png',
#  'Lara\\angle_+00-45+10.png',
#  'Lara\\angle_+00-45+15.png',
#  'Lara\\angle_+00-45+20.png',
#  'Lara\\angle_+00-45-05(1).png',
#  'Lara\\angle_+00-45-05.png',
#  'Lara\\angle_+00-45-10.png',
#  'Lara\\angle_+00-45-15.png',
#  'Lara\\angle_+00-45-20.png',
#  'Lara\\angle_+05+00+00.png',
#  'Lara\\angle_+05+00+05.png',
#  'Lara\\angle_+05+00+10.png',
#  'Lara\\angle_+05+00+15.png',
#  'Lara\\angle_+05+00+20.png',
#  'Lara\\angle_+05+00-05.png',
#  'Lara\\angle_+05+00-10.png',
#  'Lara\\angle_+05+00-15.png',
#  'Lara\\angle_+05+00-20.png',
#  'Lara\\angle_+05+05+00.png',
#  'Lara\\angle_+05+05+05.png',
#  'Lara\\angle_+05+05+10.png',
#  'Lara\\angle_+05+05+15.png',
#  'Lara\\angle_+05+05+20.png',
#  'Lara\\angle_+05+05-05.png',
#  'Lara\\angle_+05+05-10.png',
#  'Lara\\angle_+05+05-15.png',
#  'Lara\\angle_+05+05-20.png',
#  'Lara\\angle_+05+10+00.png',
#  'Lara\\angle_+05+10+05.png',
#  'Lara\\angle_+05+10+10.png',
#  'Lara\\angle_+05+10+15.png',
#  'Lara\\angle_+05+10+20.png',
#  'Lara\\angle_+05+10-05.png',
#  'Lara\\angle_+05+10-10.png',
#  'Lara\\angle_+05+10-15.png',
#  'Lara\\angle_+05+10-20.png',
#  'Lara\\angle_+05+15+00.png',
#  'Lara\\angle_+05+15+05.png',
#  'Lara\\angle_+05+15+10.png',
#  'Lara\\angle_+05+15+15.png',
#  'Lara\\angle_+05+15+20.png',
#  'Lara\\angle_+05+15-05.png',
#  'Lara\\angle_+05+15-10.png',
#  'Lara\\angle_+05+15-15.png',
#  'Lara\\angle_+05+15-20.png',
#  'Lara\\angle_+05+20+00.png',
#  'Lara\\angle_+05+20+05.png',
#  'Lara\\angle_+05+20+10.png',
#  'Lara\\angle_+05+20+15.png',
#  'Lara\\angle_+05+20+20.png',
#  'Lara\\angle_+05+20-05(1).png',
#  'Lara\\angle_+05+20-05.png',
#  'Lara\\angle_+05+20-10.png',
#  'Lara\\angle_+05+20-15.png',
#  'Lara\\angle_+05+20-20.png',
#  'Lara\\angle_+05+25+00.png',
#  'Lara\\angle_+05+25+05(1).png',
#  'Lara\\angle_+05+25+05.png',
#  'Lara\\angle_+05+25+10.png',
#  'Lara\\angle_+05+25+15.png',
#  'Lara\\angle_+05+25+20.png',
#  'Lara\\angle_+05+25-05.png',
#  'Lara\\angle_+05+25-10.png',
#  'Lara\\angle_+05+25-15.png',
#  'Lara\\angle_+05+25-20.png',
#  'Lara\\angle_+05+30+00.png',
#  'Lara\\angle_+05+30+05.png',
#  'Lara\\angle_+05+30+10.png',
#  'Lara\\angle_+05+30+15.png',
#  'Lara\\angle_+05+30+20.png',
#  'Lara\\angle_+05+30-05.png',
#  'Lara\\angle_+05+30-10.png',
#  'Lara\\angle_+05+30-15.png',
#  'Lara\\angle_+05+30-20(1).png',
#  'Lara\\angle_+05+30-20.png',
#  'Lara\\angle_+05+35+00.png',
#  'Lara\\angle_+05+35+05.png',
#  'Lara\\angle_+05+35+10.png',
#  'Lara\\angle_+05+35+15.png',
#  'Lara\\angle_+05+35+20.png',
#  'Lara\\angle_+05+35-05.png',
#  'Lara\\angle_+05+35-10(1).png',
#  'Lara\\angle_+05+35-10.png',
#  'Lara\\angle_+05+35-15.png',
#  'Lara\\angle_+05+35-20.png',
#  'Lara\\angle_+05+40+00.png',
#  'Lara\\angle_+05+40+05.png',
#  'Lara\\angle_+05+40+10.png',
#  'Lara\\angle_+05+40+15.png',
#  'Lara\\angle_+05+40+20.png',
#  'Lara\\angle_+05+40-05.png',
#  'Lara\\angle_+05+40-10.png',
#  'Lara\\angle_+05+40-15.png',
#  'Lara\\angle_+05+40-20.png',
#  'Lara\\angle_+05+45+00.png',
#  'Lara\\angle_+05+45+05.png',
#  'Lara\\angle_+05+45+10.png',
#  'Lara\\angle_+05+45+15.png',
#  'Lara\\angle_+05+45+20.png',
#  'Lara\\angle_+05+45-05.png',
#  'Lara\\angle_+05+45-10.png',
#  'Lara\\angle_+05+45-15.png',
#  'Lara\\angle_+05+45-20.png',
#  'Lara\\angle_+05-05+00.png',
#  'Lara\\angle_+05-05+05(1).png',
#  'Lara\\angle_+05-05+05.png',
#  'Lara\\angle_+05-05+10.png',
#  'Lara\\angle_+05-05+15.png',
#  'Lara\\angle_+05-05+20.png',
#  'Lara\\angle_+05-05-05.png',
#  'Lara\\angle_+05-05-10.png',
#  'Lara\\angle_+05-05-15.png',
#  'Lara\\angle_+05-05-20.png',
#  'Lara\\angle_+05-10+00.png',
#  'Lara\\angle_+05-10+05.png',
#  'Lara\\angle_+05-10+10.png',
#  'Lara\\angle_+05-10+15.png',
#  'Lara\\angle_+05-10+20.png',
#  'Lara\\angle_+05-10-05.png',
#  'Lara\\angle_+05-10-10.png',
#  'Lara\\angle_+05-10-15.png',
#  'Lara\\angle_+05-10-20(1).png',
#  'Lara\\angle_+05-10-20.png',
#  'Lara\\angle_+05-15+00.png',
#  'Lara\\angle_+05-15+05.png',
#  'Lara\\angle_+05-15+10.png',
#  'Lara\\angle_+05-15+15.png',
#  'Lara\\angle_+05-15+20.png',
#  'Lara\\angle_+05-15-05.png',
#  'Lara\\angle_+05-15-10.png',
#  'Lara\\angle_+05-15-15.png',
#  'Lara\\angle_+05-15-20.png',
#  'Lara\\angle_+05-20+00.png',
#  'Lara\\angle_+05-20+05.png',
#  'Lara\\angle_+05-20+10.png',
#  'Lara\\angle_+05-20+15.png',
#  'Lara\\angle_+05-20+20.png',
#  'Lara\\angle_+05-20-05.png',
#  'Lara\\angle_+05-20-10.png',
#  'Lara\\angle_+05-20-15.png',
#  'Lara\\angle_+05-20-20.png',
#  'Lara\\angle_+05-25+00.png',
#  'Lara\\angle_+05-25+05.png',
#  'Lara\\angle_+05-25+10.png',
#  'Lara\\angle_+05-25+15.png',
#  'Lara\\angle_+05-25+20.png',
#  'Lara\\angle_+05-25-05.png',
#  'Lara\\angle_+05-25-10.png',
#  'Lara\\angle_+05-25-15.png',
#  'Lara\\angle_+05-25-20.png',
#  'Lara\\angle_+05-30+00.png',
#  'Lara\\angle_+05-30+05.png',
#  'Lara\\angle_+05-30+10.png',
#  'Lara\\angle_+05-30+15.png',
#  'Lara\\angle_+05-30+20.png',
#  'Lara\\angle_+05-30-05.png',
#  'Lara\\angle_+05-30-10.png',
#  'Lara\\angle_+05-30-15.png',
#  'Lara\\angle_+05-30-20.png',
#  'Lara\\angle_+05-35+00.png',
#  'Lara\\angle_+05-35+05.png',
#  'Lara\\angle_+05-35+10.png',
#  'Lara\\angle_+05-35+15.png',
#  'Lara\\angle_+05-35+20.png',
#  'Lara\\angle_+05-35-05.png',
#  'Lara\\angle_+05-35-10.png',
#  'Lara\\angle_+05-35-15.png',
#  'Lara\\angle_+05-35-20.png',
#  'Lara\\angle_+05-40+00.png',
#  'Lara\\angle_+05-40+05.png',
#  'Lara\\angle_+05-40+10.png',
#  'Lara\\angle_+05-40+15.png',
#  'Lara\\angle_+05-40+20.png',
#  'Lara\\angle_+05-40-05(1).png',
#  'Lara\\angle_+05-40-05.png',
#  'Lara\\angle_+05-40-10.png',
#  'Lara\\angle_+05-40-15.png',
#  'Lara\\angle_+05-40-20.png',
#  'Lara\\angle_+05-45+00.png',
#  'Lara\\angle_+05-45+05.png',
#  'Lara\\angle_+05-45+10.png',
#  'Lara\\angle_+05-45+15.png',
#  'Lara\\angle_+05-45+20.png',
#  'Lara\\angle_+05-45-05.png',
#  'Lara\\angle_+05-45-10.png',
#  'Lara\\angle_+05-45-15.png',
#  'Lara\\angle_+05-45-20.png',
#  'Lara\\angle_+10+00+00.png',
#  'Lara\\angle_+10+00+05.png',
#  'Lara\\angle_+10+00+10.png',
#  'Lara\\angle_+10+00+15.png',
#  'Lara\\angle_+10+00+20.png',
#  'Lara\\angle_+10+00-05.png',
#  'Lara\\angle_+10+00-10.png',
#  'Lara\\angle_+10+00-15.png',
#  'Lara\\angle_+10+00-20.png',
#  'Lara\\angle_+10+05+00.png',
#  'Lara\\angle_+10+05+05.png',
#  'Lara\\angle_+10+05+10.png',
#  'Lara\\angle_+10+05+15.png',
#  'Lara\\angle_+10+05+20.png',
#  'Lara\\angle_+10+05-05.png',
#  'Lara\\angle_+10+05-10.png',
#  'Lara\\angle_+10+05-15.png',
#  'Lara\\angle_+10+05-20.png',
#  'Lara\\angle_+10+10+00.png',
#  'Lara\\angle_+10+10+05.png',
#  'Lara\\angle_+10+10+10.png',
#  'Lara\\angle_+10+10+15.png',
#  'Lara\\angle_+10+10+20(1).png',
#  'Lara\\angle_+10+10+20.png',
#  'Lara\\angle_+10+10-05.png',
#  'Lara\\angle_+10+10-10.png',
#  'Lara\\angle_+10+10-15.png',
#  'Lara\\angle_+10+10-20.png',
#  'Lara\\angle_+10+15+00.png',
#  'Lara\\angle_+10+15+05.png',
#  'Lara\\angle_+10+15+10(1).png',
#  'Lara\\angle_+10+15+10.png',
#  'Lara\\angle_+10+15+15.png',
#  'Lara\\angle_+10+15+20.png',
#  'Lara\\angle_+10+15-05.png',
#  'Lara\\angle_+10+15-10.png',
#  'Lara\\angle_+10+15-15(1).png',
#  'Lara\\angle_+10+15-15.png',
#  'Lara\\angle_+10+15-20.png',
#  'Lara\\angle_+10+20+00.png',
#  'Lara\\angle_+10+20+05.png',
#  'Lara\\angle_+10+20+10.png',
#  'Lara\\angle_+10+20+15.png',
#  'Lara\\angle_+10+20+20.png',
#  'Lara\\angle_+10+20-05.png',
#  'Lara\\angle_+10+20-10.png',
#  'Lara\\angle_+10+20-15.png',
#  'Lara\\angle_+10+20-20.png',
#  'Lara\\angle_+10+25+00.png',
#  'Lara\\angle_+10+25+05.png',
#  'Lara\\angle_+10+25+10.png',
#  'Lara\\angle_+10+25+15.png',
#  'Lara\\angle_+10+25+20.png',
#  'Lara\\angle_+10+25-05.png',
#  'Lara\\angle_+10+25-10.png',
#  'Lara\\angle_+10+25-15.png',
#  'Lara\\angle_+10+25-20.png',
#  'Lara\\angle_+10+30+00.png',
#  'Lara\\angle_+10+30+05.png',
#  'Lara\\angle_+10+30+10.png',
#  'Lara\\angle_+10+30+15.png',
#  'Lara\\angle_+10+30+20.png',
#  'Lara\\angle_+10+30-05.png',
#  'Lara\\angle_+10+30-10.png',
#  'Lara\\angle_+10+30-15.png',
#  'Lara\\angle_+10+30-20.png',
#  'Lara\\angle_+10+35+00.png',
#  'Lara\\angle_+10+35+05.png',
#  'Lara\\angle_+10+35+10.png',
#  'Lara\\angle_+10+35+15.png',
#  'Lara\\angle_+10+35+20.png',
#  'Lara\\angle_+10+35-05.png',
#  'Lara\\angle_+10+35-10.png',
#  'Lara\\angle_+10+35-15.png',
#  'Lara\\angle_+10+35-20.png',
#  'Lara\\angle_+10+40+00.png',
#  'Lara\\angle_+10+40+05(1).png',
#  'Lara\\angle_+10+40+05.png',
#  'Lara\\angle_+10+40+10.png',
#  'Lara\\angle_+10+40+15.png',
#  'Lara\\angle_+10+40+20.png',
#  'Lara\\angle_+10+40-05.png',
#  'Lara\\angle_+10+40-10.png',
#  'Lara\\angle_+10+40-15.png',
#  'Lara\\angle_+10+40-20.png',
#  'Lara\\angle_+10+45+00.png',
#  'Lara\\angle_+10+45+05.png',
#  'Lara\\angle_+10+45+10.png',
#  'Lara\\angle_+10+45+15.png',
#  'Lara\\angle_+10+45+20.png',
#  'Lara\\angle_+10+45-05.png',
#  'Lara\\angle_+10+45-10.png',
#  'Lara\\angle_+10+45-15.png',
#  'Lara\\angle_+10+45-20.png',
#  'Lara\\angle_+10-05+00.png',
#  'Lara\\angle_+10-05+05.png',
#  'Lara\\angle_+10-05+10.png',
#  'Lara\\angle_+10-05+15.png',
#  'Lara\\angle_+10-05+20.png',
#  'Lara\\angle_+10-05-05.png',
#  'Lara\\angle_+10-05-10.png',
#  'Lara\\angle_+10-05-15.png',
#  'Lara\\angle_+10-05-20.png',
#  'Lara\\angle_+10-10+00.png',
#  'Lara\\angle_+10-10+05.png',
#  'Lara\\angle_+10-10+10.png',
#  'Lara\\angle_+10-10+15.png',
#  'Lara\\angle_+10-10+20.png',
#  'Lara\\angle_+10-10-05.png',
#  'Lara\\angle_+10-10-10.png',
#  'Lara\\angle_+10-10-15.png',
#  'Lara\\angle_+10-10-20.png',
#  'Lara\\angle_+10-15+00.png',
#  'Lara\\angle_+10-15+05.png',
#  'Lara\\angle_+10-15+10.png',
#  'Lara\\angle_+10-15+15.png',
#  'Lara\\angle_+10-15+20.png',
#  'Lara\\angle_+10-15-05.png',
#  'Lara\\angle_+10-15-10.png',
#  'Lara\\angle_+10-15-15.png',
#  'Lara\\angle_+10-15-20.png',
#  'Lara\\angle_+10-20+00.png',
#  'Lara\\angle_+10-20+05.png',
#  'Lara\\angle_+10-20+10.png',
#  'Lara\\angle_+10-20+15.png',
#  'Lara\\angle_+10-20+20.png',
#  'Lara\\angle_+10-20-05.png',
#  'Lara\\angle_+10-20-10.png',
#  'Lara\\angle_+10-20-15.png',
#  'Lara\\angle_+10-20-20(1).png',
#  'Lara\\angle_+10-20-20.png',
#  'Lara\\angle_+10-25+00.png',
#  'Lara\\angle_+10-25+05.png',
#  'Lara\\angle_+10-25+10.png',
#  'Lara\\angle_+10-25+15.png',
#  'Lara\\angle_+10-25+20.png',
#  'Lara\\angle_+10-25-05(1).png',
#  'Lara\\angle_+10-25-05.png',
#  'Lara\\angle_+10-25-10.png',
#  'Lara\\angle_+10-25-15.png',
#  'Lara\\angle_+10-25-20.png',
#  'Lara\\angle_+10-30+00.png',
#  'Lara\\angle_+10-30+05.png',
#  'Lara\\angle_+10-30+10.png',
#  'Lara\\angle_+10-30+15.png',
#  'Lara\\angle_+10-30+20(1).png',
#  'Lara\\angle_+10-30+20.png',
#  'Lara\\angle_+10-30-05.png',
#  'Lara\\angle_+10-30-10.png',
#  'Lara\\angle_+10-30-15.png',
#  'Lara\\angle_+10-30-20.png',
#  'Lara\\angle_+10-35+00.png',
#  'Lara\\angle_+10-35+05.png',
#  'Lara\\angle_+10-35+10.png',
#  'Lara\\angle_+10-35+15.png',
#  'Lara\\angle_+10-35+20.png',
#  'Lara\\angle_+10-35-05.png',
#  'Lara\\angle_+10-35-10.png',
#  'Lara\\angle_+10-35-15.png',
#  'Lara\\angle_+10-35-20.png',
#  'Lara\\angle_+10-40+00.png',
#  'Lara\\angle_+10-40+05.png',
#  'Lara\\angle_+10-40+10.png',
#  'Lara\\angle_+10-40+15.png',
#  'Lara\\angle_+10-40+20.png',
#  'Lara\\angle_+10-40-05.png',
#  'Lara\\angle_+10-40-10.png',
#  'Lara\\angle_+10-40-15.png',
#  'Lara\\angle_+10-40-20.png',
#  'Lara\\angle_+10-45+00.png',
#  'Lara\\angle_+10-45+05.png',
#  'Lara\\angle_+10-45+10.png',
#  'Lara\\angle_+10-45+15.png',
#  'Lara\\angle_+10-45+20.png',
#  'Lara\\angle_+10-45-05.png',
#  'Lara\\angle_+10-45-10.png',
#  'Lara\\angle_+10-45-15.png',
#  'Lara\\angle_+10-45-20.png',
#  'Lara\\angle_+15+00+00(1).png',
#  'Lara\\angle_+15+00+00.png',
#  'Lara\\angle_+15+00+05.png',
#  'Lara\\angle_+15+00+10.png',
#  'Lara\\angle_+15+00+15.png',
#  'Lara\\angle_+15+00+20.png',
#  'Lara\\angle_+15+00-05.png',
#  'Lara\\angle_+15+00-10(1).png',
#  'Lara\\angle_+15+00-10.png',
#  'Lara\\angle_+15+00-15.png',
#  'Lara\\angle_+15+00-20.png',
#  'Lara\\angle_+15+05+00.png',
#  'Lara\\angle_+15+05+05.png',
#  'Lara\\angle_+15+05+10.png',
#  'Lara\\angle_+15+05+15.png',
#  'Lara\\angle_+15+05+20.png',
#  'Lara\\angle_+15+05-05.png',
#  'Lara\\angle_+15+05-10.png',
#  'Lara\\angle_+15+05-15.png',
#  'Lara\\angle_+15+05-20.png',
#  'Lara\\angle_+15+10+00.png',
#  'Lara\\angle_+15+10+05.png',
#  'Lara\\angle_+15+10+10.png',
#  'Lara\\angle_+15+10+15.png',
#  'Lara\\angle_+15+10+20.png',
#  'Lara\\angle_+15+10-05.png',
#  'Lara\\angle_+15+10-10.png',
#  'Lara\\angle_+15+10-15(1).png',
#  'Lara\\angle_+15+10-15.png',
#  'Lara\\angle_+15+10-20.png',
#  'Lara\\angle_+15+15+00.png',
#  'Lara\\angle_+15+15+05.png',
#  'Lara\\angle_+15+15+10.png',
#  'Lara\\angle_+15+15+15.png',
#  'Lara\\angle_+15+15+20.png',
#  'Lara\\angle_+15+15-05.png',
#  'Lara\\angle_+15+15-10.png',
#  'Lara\\angle_+15+15-15.png',
#  'Lara\\angle_+15+15-20.png',
#  'Lara\\angle_+15+20+00.png',
#  'Lara\\angle_+15+20+05.png',
#  'Lara\\angle_+15+20+10.png',
#  'Lara\\angle_+15+20+15.png',
#  'Lara\\angle_+15+20+20.png',
#  'Lara\\angle_+15+20-05.png',
#  'Lara\\angle_+15+20-10.png',
#  'Lara\\angle_+15+20-15.png',
#  'Lara\\angle_+15+20-20.png',
#  'Lara\\angle_+15+25+00.png',
#  'Lara\\angle_+15+25+05.png',
#  'Lara\\angle_+15+25+10.png',
#  'Lara\\angle_+15+25+15.png',
#  'Lara\\angle_+15+25+20.png',
#  'Lara\\angle_+15+25-05.png',
#  'Lara\\angle_+15+25-10.png',
#  'Lara\\angle_+15+25-15.png',
#  'Lara\\angle_+15+25-20.png',
#  'Lara\\angle_+15+30+00.png',
#  'Lara\\angle_+15+30+05.png',
#  'Lara\\angle_+15+30+10.png',
#  'Lara\\angle_+15+30+15.png',
#  'Lara\\angle_+15+30+20.png',
#  'Lara\\angle_+15+30-05.png',
#  'Lara\\angle_+15+30-10.png',
#  'Lara\\angle_+15+30-15.png',
#  'Lara\\angle_+15+30-20.png',
#  'Lara\\angle_+15+35+00.png',
#  'Lara\\angle_+15+35+05.png',
#  'Lara\\angle_+15+35+10.png',
#  'Lara\\angle_+15+35+15.png',
#  'Lara\\angle_+15+35+20.png',
#  'Lara\\angle_+15+35-05.png',
#  'Lara\\angle_+15+35-10.png',
#  'Lara\\angle_+15+35-15.png',
#  'Lara\\angle_+15+35-20.png',
#  'Lara\\angle_+15+40+00.png',
#  'Lara\\angle_+15+40+05.png',
#  'Lara\\angle_+15+40+10.png',
#  'Lara\\angle_+15+40+15.png',
#  'Lara\\angle_+15+40+20(1).png',
#  'Lara\\angle_+15+40+20.png',
#  'Lara\\angle_+15+40-05.png',
#  'Lara\\angle_+15+40-10.png',
#  'Lara\\angle_+15+40-15.png',
#  'Lara\\angle_+15+40-20.png',
#  'Lara\\angle_+15+45+00.png',
#  'Lara\\angle_+15+45+05.png',
#  'Lara\\angle_+15+45+10.png',
#  'Lara\\angle_+15+45+15.png',
#  'Lara\\angle_+15+45+20.png',
#  'Lara\\angle_+15+45-05.png',
#  'Lara\\angle_+15+45-10.png',
#  'Lara\\angle_+15+45-15.png',
#  'Lara\\angle_+15+45-20.png',
#  'Lara\\angle_+15-05+00.png',
#  'Lara\\angle_+15-05+05.png',
#  'Lara\\angle_+15-05+10.png',
#  'Lara\\angle_+15-05+15.png',
#  'Lara\\angle_+15-05+20.png',
#  'Lara\\angle_+15-05-05.png',
#  'Lara\\angle_+15-05-10.png',
#  'Lara\\angle_+15-05-15.png',
#  'Lara\\angle_+15-05-20.png',
#  'Lara\\angle_+15-10+00.png',
#  'Lara\\angle_+15-10+05.png',
#  'Lara\\angle_+15-10+10.png',
#  'Lara\\angle_+15-10+15.png',
#  'Lara\\angle_+15-10+20.png',
#  'Lara\\angle_+15-10-05.png',
#  'Lara\\angle_+15-10-10.png',
#  'Lara\\angle_+15-10-15.png',
#  'Lara\\angle_+15-10-20.png',
#  'Lara\\angle_+15-15+00.png',
#  'Lara\\angle_+15-15+05.png',
#  'Lara\\angle_+15-15+10.png',
#  'Lara\\angle_+15-15+15.png',
#  'Lara\\angle_+15-15+20.png',
#  'Lara\\angle_+15-15-05.png',
#  'Lara\\angle_+15-15-10.png',
#  'Lara\\angle_+15-15-15.png',
#  'Lara\\angle_+15-15-20.png',
#  'Lara\\angle_+15-20+00.png',
#  'Lara\\angle_+15-20+05.png',
#  'Lara\\angle_+15-20+10.png',
#  'Lara\\angle_+15-20+15.png',
#  'Lara\\angle_+15-20+20.png',
#  'Lara\\angle_+15-20-05.png',
#  'Lara\\angle_+15-20-10.png',
#  'Lara\\angle_+15-20-15.png',
#  'Lara\\angle_+15-20-20.png',
#  'Lara\\angle_+15-25+00.png',
#  'Lara\\angle_+15-25+05.png',
#  'Lara\\angle_+15-25+10.png',
#  'Lara\\angle_+15-25+15.png',
#  'Lara\\angle_+15-25+20.png',
#  'Lara\\angle_+15-25-05.png',
#  'Lara\\angle_+15-25-10.png',
#  'Lara\\angle_+15-25-15.png',
#  'Lara\\angle_+15-25-20.png',
#  'Lara\\angle_+15-30+00.png',
#  'Lara\\angle_+15-30+05.png',
#  'Lara\\angle_+15-30+10(1).png',
#  'Lara\\angle_+15-30+10.png',
#  'Lara\\angle_+15-30+15.png',
#  'Lara\\angle_+15-30+20.png',
#  'Lara\\angle_+15-30-05.png',
#  'Lara\\angle_+15-30-10.png',
#  'Lara\\angle_+15-30-15(1).png',
#  'Lara\\angle_+15-30-15.png',
#  'Lara\\angle_+15-30-20.png',
#  'Lara\\angle_+15-35+00.png',
#  'Lara\\angle_+15-35+05.png',
#  'Lara\\angle_+15-35+10.png',
#  'Lara\\angle_+15-35+15.png',
#  'Lara\\angle_+15-35+20.png',
#  'Lara\\angle_+15-35-05.png',
#  'Lara\\angle_+15-35-10.png',
#  'Lara\\angle_+15-35-15.png',
#  'Lara\\angle_+15-35-20.png',
#  'Lara\\angle_+15-40+00.png',
#  'Lara\\angle_+15-40+05.png',
#  'Lara\\angle_+15-40+10.png',
#  'Lara\\angle_+15-40+15.png',
#  'Lara\\angle_+15-40+20.png',
#  'Lara\\angle_+15-40-05.png',
#  'Lara\\angle_+15-40-10.png',
#  'Lara\\angle_+15-40-15.png',
#  'Lara\\angle_+15-40-20.png',
#  'Lara\\angle_+15-45+00.png',
#  'Lara\\angle_+15-45+05.png',
#  'Lara\\angle_+15-45+10.png',
#  'Lara\\angle_+15-45+15.png',
#  'Lara\\angle_+15-45+20.png',
#  'Lara\\angle_+15-45-05.png',
#  'Lara\\angle_+15-45-10.png',
#  'Lara\\angle_+15-45-15.png',
#  'Lara\\angle_+15-45-20.png',
#  'Lara\\angle_+20+00+00.png',
#  'Lara\\angle_+20+00+05.png',
#  'Lara\\angle_+20+00+10.png',
#  'Lara\\angle_+20+00+15(1).png',
#  'Lara\\angle_+20+00+15.png',
#  'Lara\\angle_+20+00+20.png',
#  'Lara\\angle_+20+00-05.png',
#  'Lara\\angle_+20+00-10.png',
#  'Lara\\angle_+20+00-15.png',
#  'Lara\\angle_+20+00-20.png',
#  'Lara\\angle_+20+05+00.png',
#  'Lara\\angle_+20+05+05.png',
#  'Lara\\angle_+20+05+10.png',
#  'Lara\\angle_+20+05+15.png',
#  'Lara\\angle_+20+05+20.png',
#  'Lara\\angle_+20+05-05.png',
#  'Lara\\angle_+20+05-10.png',
#  'Lara\\angle_+20+05-15.png',
#  'Lara\\angle_+20+05-20.png',
#  'Lara\\angle_+20+10+00.png',
#  'Lara\\angle_+20+10+05(1).png',
#  'Lara\\angle_+20+10+05.png',
#  'Lara\\angle_+20+10+10.png',
#  'Lara\\angle_+20+10+15.png',
#  'Lara\\angle_+20+10+20.png',
#  'Lara\\angle_+20+10-05.png',
#  'Lara\\angle_+20+10-10.png',
#  'Lara\\angle_+20+10-15.png',
#  'Lara\\angle_+20+10-20.png',
#  'Lara\\angle_+20+15+00.png',
#  'Lara\\angle_+20+15+05.png',
#  'Lara\\angle_+20+15+10.png',
#  'Lara\\angle_+20+15+15.png',
#  'Lara\\angle_+20+15+20(1).png',
#  'Lara\\angle_+20+15+20.png',
#  'Lara\\angle_+20+15-05.png',
#  'Lara\\angle_+20+15-10(1).png',
#  'Lara\\angle_+20+15-10.png',
#  'Lara\\angle_+20+15-15.png',
#  'Lara\\angle_+20+15-20.png',
#  'Lara\\angle_+20+20+00.png',
#  'Lara\\angle_+20+20+05.png',
#  'Lara\\angle_+20+20+10.png',
#  'Lara\\angle_+20+20+15.png',
#  'Lara\\angle_+20+20+20.png',
#  'Lara\\angle_+20+20-05.png',
#  'Lara\\angle_+20+20-10.png',
#  'Lara\\angle_+20+20-15.png',
#  'Lara\\angle_+20+20-20.png',
#  'Lara\\angle_+20+25+00.png',
#  'Lara\\angle_+20+25+05.png',
#  'Lara\\angle_+20+25+10.png',
#  'Lara\\angle_+20+25+15.png',
#  'Lara\\angle_+20+25+20.png',
#  'Lara\\angle_+20+25-05.png',
#  'Lara\\angle_+20+25-10.png',
#  'Lara\\angle_+20+25-15.png',
#  'Lara\\angle_+20+25-20.png',
#  'Lara\\angle_+20+30+00.png',
#  'Lara\\angle_+20+30+05.png',
#  'Lara\\angle_+20+30+10.png',
#  'Lara\\angle_+20+30+15.png',
#  'Lara\\angle_+20+30+20.png',
#  'Lara\\angle_+20+30-05.png',
#  'Lara\\angle_+20+30-10.png',
#  'Lara\\angle_+20+30-15.png',
#  'Lara\\angle_+20+30-20.png',
#  'Lara\\angle_+20+35+00.png',
#  'Lara\\angle_+20+35+05.png',
#  'Lara\\angle_+20+35+10.png',
#  'Lara\\angle_+20+35+15.png',
#  'Lara\\angle_+20+35+20.png',
#  'Lara\\angle_+20+35-05.png',
#  'Lara\\angle_+20+35-10.png',
#  'Lara\\angle_+20+35-15.png',
#  'Lara\\angle_+20+35-20.png',
#  'Lara\\angle_+20+40+00.png',
#  'Lara\\angle_+20+40+05.png',
#  'Lara\\angle_+20+40+10.png',
#  'Lara\\angle_+20+40+15.png',
#  'Lara\\angle_+20+40+20.png',
#  'Lara\\angle_+20+40-05(1).png',
#  'Lara\\angle_+20+40-05.png',
#  'Lara\\angle_+20+40-10.png',
#  'Lara\\angle_+20+40-15.png',
#  'Lara\\angle_+20+40-20.png',
#  'Lara\\angle_+20+45+00.png',
#  'Lara\\angle_+20+45+05(1).png',
#  'Lara\\angle_+20+45+05.png',
#  'Lara\\angle_+20+45+10.png',
#  'Lara\\angle_+20+45+15.png',
#  'Lara\\angle_+20+45+20.png',
#  'Lara\\angle_+20+45-05.png',
#  'Lara\\angle_+20+45-10.png',
#  'Lara\\angle_+20+45-15.png',
#  'Lara\\angle_+20+45-20.png',
#  'Lara\\angle_+20-05+00.png',
#  'Lara\\angle_+20-05+05.png',
#  'Lara\\angle_+20-05+10.png',
#  'Lara\\angle_+20-05+15.png',
#  'Lara\\angle_+20-05+20.png',
#  'Lara\\angle_+20-05-05.png',
#  'Lara\\angle_+20-05-10.png',
#  'Lara\\angle_+20-05-15.png',
#  'Lara\\angle_+20-05-20.png',
#  'Lara\\angle_+20-10+00.png',
#  'Lara\\angle_+20-10+05.png',
#  'Lara\\angle_+20-10+10.png',
#  'Lara\\angle_+20-10+15.png',
#  'Lara\\angle_+20-10+20.png',
#  'Lara\\angle_+20-10-05.png',
#  'Lara\\angle_+20-10-10.png',
#  'Lara\\angle_+20-10-15.png',
#  'Lara\\angle_+20-10-20.png',
#  'Lara\\angle_+20-15+00.png',
#  'Lara\\angle_+20-15+05.png',
#  'Lara\\angle_+20-15+10.png',
#  'Lara\\angle_+20-15+15.png',
#  'Lara\\angle_+20-15+20.png',
#  'Lara\\angle_+20-15-05.png',
#  'Lara\\angle_+20-15-10.png',
#  'Lara\\angle_+20-15-15.png',
#  'Lara\\angle_+20-15-20.png',
#  'Lara\\angle_+20-20+00.png',
#  'Lara\\angle_+20-20+05.png',
#  'Lara\\angle_+20-20+10.png',
#  'Lara\\angle_+20-20+15.png',
#  'Lara\\angle_+20-20+20.png',
#  'Lara\\angle_+20-20-05(1).png',
#  'Lara\\angle_+20-20-05.png',
#  'Lara\\angle_+20-20-10.png',
#  'Lara\\angle_+20-20-15.png',
#  'Lara\\angle_+20-20-20.png',
#  'Lara\\angle_+20-25+00.png',
#  'Lara\\angle_+20-25+05.png',
#  'Lara\\angle_+20-25+10.png',
#  'Lara\\angle_+20-25+15.png',
#  'Lara\\angle_+20-25+20.png',
#  'Lara\\angle_+20-25-05.png',
#  'Lara\\angle_+20-25-10.png',
#  'Lara\\angle_+20-25-15.png',
#  'Lara\\angle_+20-25-20.png',
#  'Lara\\angle_+20-30+00.png',
#  'Lara\\angle_+20-30+05.png',
#  'Lara\\angle_+20-30+10.png',
#  'Lara\\angle_+20-30+15.png',
#  'Lara\\angle_+20-30+20.png',
#  'Lara\\angle_+20-30-05.png',
#  'Lara\\angle_+20-30-10.png',
#  'Lara\\angle_+20-30-15(1).png',
#  'Lara\\angle_+20-30-15.png',
#  'Lara\\angle_+20-30-20.png',
#  'Lara\\angle_+20-35+00.png',
#  'Lara\\angle_+20-35+05.png',
#  'Lara\\angle_+20-35+10.png',
#  'Lara\\angle_+20-35+15.png',
#  'Lara\\angle_+20-35+20(1).png',
#  'Lara\\angle_+20-35+20.png',
#  'Lara\\angle_+20-35-05.png',
#  'Lara\\angle_+20-35-10.png',
#  'Lara\\angle_+20-35-15.png',
#  'Lara\\angle_+20-35-20.png',
#  'Lara\\angle_+20-40+00.png',
#  'Lara\\angle_+20-40+05.png',
#  'Lara\\angle_+20-40+10.png',
#  'Lara\\angle_+20-40+15.png',
#  'Lara\\angle_+20-40+20.png',
#  'Lara\\angle_+20-40-05.png',
#  'Lara\\angle_+20-40-10.png',
#  'Lara\\angle_+20-40-15.png',
#  'Lara\\angle_+20-40-20.png',
#  'Lara\\angle_+20-45+00.png',
#  'Lara\\angle_+20-45+05.png',
#  'Lara\\angle_+20-45+10.png',
#  'Lara\\angle_+20-45+15.png',
#  'Lara\\angle_+20-45+20.png',
#  'Lara\\angle_+20-45-05.png',
#  'Lara\\angle_+20-45-10.png',
#  'Lara\\angle_+20-45-15.png',
#  'Lara\\angle_+20-45-20.png',
#  'Lara\\angle_+25+00+00.png',
#  'Lara\\angle_+25+00+05.png',
#  'Lara\\angle_+25+00+10.png',
#  'Lara\\angle_+25+00+15.png',
#  'Lara\\angle_+25+00+20.png',
#  'Lara\\angle_+25+00-05.png',
#  'Lara\\angle_+25+00-10.png',
#  'Lara\\angle_+25+00-15.png',
#  'Lara\\angle_+25+00-20.png',
#  'Lara\\angle_+25+05+00.png',
#  'Lara\\angle_+25+05+05.png',
#  'Lara\\angle_+25+05+10.png',
#  'Lara\\angle_+25+05+15.png',
#  'Lara\\angle_+25+05+20.png',
#  'Lara\\angle_+25+05-05.png',
#  'Lara\\angle_+25+05-10.png',
#  'Lara\\angle_+25+05-15.png',
#  'Lara\\angle_+25+05-20.png',
#  'Lara\\angle_+25+10+00.png',
#  'Lara\\angle_+25+10+05.png',
#  'Lara\\angle_+25+10+10.png',
#  'Lara\\angle_+25+10+15.png',
#  'Lara\\angle_+25+10+20.png',
#  'Lara\\angle_+25+10-05.png',
#  'Lara\\angle_+25+10-10.png',
#  'Lara\\angle_+25+10-15.png',
#  'Lara\\angle_+25+10-20.png',
#  'Lara\\angle_+25+15+00.png',
#  'Lara\\angle_+25+15+05.png',
#  'Lara\\angle_+25+15+10(1).png',
#  'Lara\\angle_+25+15+10.png',
#  'Lara\\angle_+25+15+15.png',
#  'Lara\\angle_+25+15+20.png',
#  'Lara\\angle_+25+15-05.png',
#  'Lara\\angle_+25+15-10.png',
#  'Lara\\angle_+25+15-15.png',
#  'Lara\\angle_+25+15-20.png',
#  'Lara\\angle_+25+20+00.png',
#  'Lara\\angle_+25+20+05.png',
#  'Lara\\angle_+25+20+10.png',
#  'Lara\\angle_+25+20+15.png',
#  'Lara\\angle_+25+20+20.png',
#  'Lara\\angle_+25+20-05.png',
#  'Lara\\angle_+25+20-10.png',
#  'Lara\\angle_+25+20-15.png',
#  'Lara\\angle_+25+20-20.png',
#  'Lara\\angle_+25+25+00.png',
#  'Lara\\angle_+25+25+05.png',
#  'Lara\\angle_+25+25+10.png',
#  'Lara\\angle_+25+25+15.png',
#  'Lara\\angle_+25+25+20.png',
#  'Lara\\angle_+25+25-05.png',
#  'Lara\\angle_+25+25-10.png',
#  'Lara\\angle_+25+25-15.png',
#  'Lara\\angle_+25+25-20.png',
#  'Lara\\angle_+25+30+00.png',
#  'Lara\\angle_+25+30+05.png',
#  'Lara\\angle_+25+30+10.png',
#  'Lara\\angle_+25+30+15.png',
#  'Lara\\angle_+25+30+20.png',
#  'Lara\\angle_+25+30-05.png',
#  'Lara\\angle_+25+30-10.png',
#  'Lara\\angle_+25+30-15.png',
#  'Lara\\angle_+25+30-20.png',
#  'Lara\\angle_+25+35+00.png',
#  'Lara\\angle_+25+35+05.png',
#  'Lara\\angle_+25+35+10.png',
#  'Lara\\angle_+25+35+15.png',
#  'Lara\\angle_+25+35+20.png',
#  'Lara\\angle_+25+35-05.png',
#  'Lara\\angle_+25+35-10.png',
#  'Lara\\angle_+25+35-15.png',
#  'Lara\\angle_+25+35-20.png',
#  'Lara\\angle_+25+40+00.png',
#  'Lara\\angle_+25+40+05(1).png',
#  'Lara\\angle_+25+40+05.png',
#  'Lara\\angle_+25+40+10.png',
#  'Lara\\angle_+25+40+15.png',
#  'Lara\\angle_+25+40+20.png',
#  'Lara\\angle_+25+40-05.png',
#  'Lara\\angle_+25+40-10.png',
#  'Lara\\angle_+25+40-15.png',
#  'Lara\\angle_+25+40-20.png',
#  'Lara\\angle_+25+45+00.png',
#  'Lara\\angle_+25+45+05.png',
#  'Lara\\angle_+25+45+10.png',
#  'Lara\\angle_+25+45+15.png',
#  'Lara\\angle_+25+45+20.png',
#  'Lara\\angle_+25+45-05.png',
#  'Lara\\angle_+25+45-10.png',
#  'Lara\\angle_+25+45-15.png',
#  'Lara\\angle_+25+45-20.png',
#  'Lara\\angle_+25-05+00.png',
#  'Lara\\angle_+25-05+05.png',
#  'Lara\\angle_+25-05+10.png',
#  'Lara\\angle_+25-05+15.png',
#  'Lara\\angle_+25-05+20.png',
#  'Lara\\angle_+25-05-05.png',
#  'Lara\\angle_+25-05-10.png',
#  'Lara\\angle_+25-05-15.png',
#  'Lara\\angle_+25-05-20.png',
#  'Lara\\angle_+25-10+00.png',
#  'Lara\\angle_+25-10+05.png',
#  'Lara\\angle_+25-10+10.png',
#  'Lara\\angle_+25-10+15.png',
#  'Lara\\angle_+25-10+20.png',
#  'Lara\\angle_+25-10-05.png',
#  'Lara\\angle_+25-10-10.png',
#  'Lara\\angle_+25-10-15.png',
#  ...]

# %%
imagepaths=np.array(paths.list_images("Lara"))

# %%
try:
    print("Library Loaded Successfully ..........")
except:
    print("Library not Found ! ")


class MasterImage(object):

    def __init__(self,PATH='', IMAGE_SIZE = 50):
        self.PATH = PATH
        self.IMAGE_SIZE = IMAGE_SIZE

        self.image_data = []
        self.x_data = []
        self.y_data = []
        self.CATEGORIES = []

        # This will get List of categories
        self.list_categories = []

    def get_categories(self):
        for path in os.listdir(self.PATH):
            if '.DS_Store' in path:
                pass
            else:
                self.list_categories.append(path)
        print("Found Categories ",self.list_categories,'\n')
        return self.list_categories

    def Process_Image(self):
        try:
            """
            Return Numpy array of image
            :return: X_Data, Y_Data
            """
            self.CATEGORIES = self.get_categories()
            for categories in self.CATEGORIES:                                                  # Iterate over categories

                train_folder_path = os.path.join(self.PATH, categories)                         # Folder Path
                class_index = self.CATEGORIES.index(categories)                                 # this will get index for classification

                for img in os.listdir(train_folder_path):                                       # This will iterate in the Folder
                    new_path = os.path.join(train_folder_path, img)                             # image Path

                    try:        # if any image is corrupted
                        image_data_temp = cv2.imread(new_path,cv2.IMREAD_GRAYSCALE)                 # Read Image as numbers
                        image_temp_resize = cv2.resize(image_data_temp,(self.IMAGE_SIZE,self.IMAGE_SIZE))
                        self.image_data.append([image_temp_resize,class_index])
                    except:
                        pass

            data = np.asanyarray(self.image_data)

            # Iterate over the Data
            for x in data:
                self.x_data.append(x[0])        # Get the X_Data
                self.y_data.append(x[1])        # get the label

            X_Data = np.asarray(self.x_data) / (255.0)      # Normalize Data
            Y_Data = np.asarray(self.y_data)

            # reshape x_Data

            X_Data = X_Data.reshape(-1, self.IMAGE_SIZE, self.IMAGE_SIZE, 1)

            return X_Data, Y_Data
        except:
            print("Failed to run Function Process Image ")

    def pickle_image(self):

        """
        :return: None Creates a Pickle Object of DataSet
        """
        # Call the Function and Get the Data
        X_Data,Y_Data = self.Process_Image()

        # Write the Entire Data into a Pickle File
        pickle_out = open('X_Data','wb')
        pickle.dump(X_Data, pickle_out)
        pickle_out.close()

        # Write the Y Label Data
        pickle_out = open('Y_Data', 'wb')
        pickle.dump(Y_Data, pickle_out)
        pickle_out.close()

        print("Pickled Image Successfully ")
        return X_Data,Y_Data

    def load_dataset(self):

        try:
            # Read the Data from Pickle Object
            X_Temp = open('X_Data','rb')
            X_Data = pickle.load(X_Temp)

            Y_Temp = open('Y_Data','rb')
            Y_Data = pickle.load(Y_Temp)

            print('Reading Dataset from PIckle Object')

            return X_Data,Y_Data

        except:
            print('Could not Found Pickle File ')
            print('Loading File and Dataset  ..........')

            X_Data,Y_Data = self.pickle_image()
            return X_Data,Y_Data
# Out:
# Library Loaded Successfully ..........

# %%
if __name__ == "__main__":
    path = r'https://drive.google.com/drive/folders/1kbb0m7nRkIfo2J04VJOycnUOYZBVPNhC?usp=sharing'
    a = MasterImage(PATH=path,
                    IMAGE_SIZE=80)

    X_Data,Y_Data = a.load_dataset()
    print(X_Data.shape)
# Out:
# Reading Dataset from PIckle Object
# (2306, 80, 80, 1)

# %%
arr = pkl.load(open(r'C:\Users\Pc\Desktop\Regressor-Face Pose\X_Data', 'rb'))
print(arr.shape)
# Out:
# (2306, 80, 80, 1)

# %%
#arr.reshape(-1,2).T
#print(x_arr.shape)

# %%
#define the roll, pitch, and yaw
roll, pitch, yaw = arr[:, 0], arr[:, 1], arr[:, 2]

#compute some statistics (min, max, mean, standard deviation)
print(roll.min(), roll.max(), roll.mean(), roll.std())
print(pitch.min(), pitch.max(), pitch.mean(), pitch.std())
print(yaw.min(), yaw.max(), yaw.mean(), yaw.std())
# Out:
# 0.9803921568627451 1.0 0.9975919595938982 0.005859637204720411
# 0.9803921568627451 1.0 0.9975919595938982 0.005859637204720411
# 0.9803921568627451 1.0 0.9975919595938982 0.005859637204720411

# %%
x_train, x_test, y_train, y_test = train_test_split(arr, arr, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1614, 80, 80, 1) (1614, 80, 80, 1)
# (346, 80, 80, 1) (346, 80, 80, 1)
# (346, 80, 80, 1) (346, 80, 80, 1)

# %%
x_train = x_train.reshape(1614,80*80*1)
x_test = x_test.reshape(346,80*80*1)
x_val = x_val.reshape(346,80*80*1)

# %%
print(x_train.shape)
print(x_test.shape)
print(x_val.shape)
# Out:
# (1614, 6400)
# (346, 6400)
# (346, 6400)

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)
y_val = np.array(y_val)

# %%
y_train = y_train.reshape(1614,80*80*1)
y_test = y_test.reshape(346,80*80*1)
y_val = y_val.reshape(346,80*80*1)

# %%
print(y_train.shape)
# Out:
# (1614, 6400)

# %%
#Scale the data
std = StandardScaler()
std.fit(x_train)
x_train = std.transform(x_train)
x_val = std.transform(x_val)
x_test = std.transform(x_test)

# %%
BATCH_SIZE = 24
EPOCHS = 100

# %%
arr = arr.reshape(*arr.shape, 1)

# %%
#build our 3-layerd model
model = Sequential()
model.add(Dense(units=15, activation='relu', kernel_regularizer='l2', input_dim=arr.shape[1]))
model.add(Dense(units=5, activation='relu', kernel_regularizer='l2'))
model.add(Dense(units=3, activation='linear'))
#'relu' output the input directly if it is positive, otherwise, it will output zero
print(model.summary())

callback_list = [EarlyStopping(monitor='val_loss', patience=25)]

model.compile(optimizer='adam', loss='mean_squared_error')
hist = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callback_list)
model.save('models/model.h5')

print()
print('Train loss:', model.evaluate(x_train, y_train, verbose=0))
print('  Val loss:', model.evaluate(x_val, y_val, verbose=0))
print(' Test loss:', model.evaluate(x_test, y_test, verbose=0))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 15)                1215
# _________________________________________________________________
# dense_22 (Dense)             (None, 5)                 80
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 18
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-ae292a8b2b92> in <module>
#      10
#      11 model.compile(optimizer='adam', loss='mean_squared_error')
# ---> 12 hist = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callback_list)
#      13 model.save('models/model.h5')
#      14
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     695     self._concrete_stateful_fn = (
# --> 696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     697             *args, **kwds))
#     698
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py:806 train_function  *
#         return step_function(self, iterator)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py:789 run_step  **
#         outputs = model.train_step(data)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py:747 train_step
#         y_pred = self(x, training=True)
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:975 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs,
#     C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:212 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential_8 is incompatible with the layer: expected axis -1 of input shape to have value 80 but received input with shape [None, 6400]

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# C:\ProgramData\Miniconda3\envs\face-pose\lib\site-packages\tensorflow\python\keras\engine\training.py in summary(self, line_length, positions, print_fn)
#    2349     """
#    2350     if not self.built:
# -> 2351       raise ValueError('This model has not yet been built. '
#    2352                        'Build the model first by calling `build()` or calling '
#    2353                        '`fit()` with some data, or specify '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data, or specify an `input_shape` argument in the first layer(s) for automatic build.

# %%
#make a figure to analyze the relation between the Train and Value-loss
history = hist.history
loss_train = history['loss']
loss_val = history['val_loss']

plt.figure()
plt.plot(loss_train, label='train')
plt.plot(loss_val, label='val_loss', color='red')
plt.legend()

# %%
y_pred = model.predict(x_test)
diff = y_test - y_pred
diff_roll = diff[:, 0]
diff_pitch = diff[:, 1]
diff_yaw = diff[:, 2]

plt.figure(figsize=(16, 10))

plt.subplot(3, 1, 1)
plt.plot(diff_roll, color='red')
plt.title('roll')

plt.subplot(3, 1, 2)
plt.plot(diff_pitch, color='red')
plt.title('pitch')

plt.subplot(3, 1, 3)
plt.plot(diff_yaw, color='red')
plt.title('yaw')

plt.tight_layout()

# %%
#detect the 68 facial landmarks through the facial landmark model
def detect_face_points(image):
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")
    face_rect = detector(image, 1)
    if len(face_rect) != 1: return []
    
    dlib_points = predictor(image, face_rect[0])
    face_points = []
    for i in range(68):
        x, y = dlib_points.part(i).x, dlib_points.part(i).y
        face_points.append(np.array([x, y]))
    return face_points

#compute the distances amongst the landmarks
def compute_features(face_points):
    assert (len(face_points) == 68), "len(face_points) must be 68"
    
    face_points = np.array(face_points)
    features = []
    for i in range(68):
        for j in range(i+1, 68):
            features.append(np.linalg.norm(face_points[i]-face_points[j]))
            
    return np.array(features).reshape(1, -1)

# %%
im = cv2.imread('data/messi.jpg', cv2.IMREAD_COLOR)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
face_points = detect_face_points(im)

for x, y in face_points:
    cv2.circle(im, (x, y), 1, (0, 255, 0), -1)
    
features = compute_features(face_points)
features = std.transform(features)

model = load_model('models/model.h5')
y_pred = model.predict(features)

roll_pred, pitch_pred, yaw_pred = y_pred[0]
print(' Roll: {:.2f}°'.format(roll_pred))
print('Pitch: {:.2f}°'.format(pitch_pred))
print('  Yaw: {:.2f}°'.format(yaw_pred))
    
plt.figure(figsize=(10, 10))
plt.imshow(im)
